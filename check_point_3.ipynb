# %% [markdown]
# #**Adidas Fashion Retail Products Dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd

# %% [markdown]
# #Business Understanding
#
# ##Business Objective
# Tujuan Pada bisnis Adidas Fashion dataset ini dimulai dari pemahaman akan kekuatan oalahraga dalam mengubah kehidupan. Pendekatan ini yang menjadikan landasan bagi pengelolaan perusahaan, untuk meningkatkan penjualan produk, kesadaran merek, dan kepuasan pelanggan, serta mengoptimalkan persediaan, ekspansi pasar, dan margin keuntungan. Selain itu, focus pada bisnis ini juga diberikan pada pengembangan produk, pengurangan biaya operasional, peningkatan retensi pelanggan, dan konversi penjualan. Dengan merumuskan objektif ini, Adidas dapat mengembangkan strategi yang tepat dan mengukur kinerja bisnis mereka berdasarkan data yang ada dalam dataset tersebut.
#
# ##Asseess Situastion
# Dalam situasi bisnis yang telah di analisis ini adalah untuk membangun fondasi yang kuat untuk masa depan dengan focus pada pengurangan investaris dan diskon pada 2023. Tujuannya untuk kembali menjadi bisnis yang menguntungkan pada tahun 2024. Adidas akan kembali menekankan pada produk, konsumen,mitra ritel,dan atlet, sambil memperkuat sumber daya manusia dan budaya perusahaan. Adidas juga harus bekerja sama dengan mitra lokal untuk meningkatkan distribusi produk dan memastikan ketersediaan produk yang memadai di toko-toko. Selain itu, Adidas perlu memperkuat kesadaran merek melalui kampanye pemasaran yang relevan dengan budaya dan tren lokal. Meskipun menghadapi tantangan,  serta mengimplementasikan langkah-langkah untuk mencapai kembali pertumbuhan yang menguntungkan. dan tetap optimis dalam melihat masa depan perusahaan.
#
# #Data Mining Goals
# Tujuan dari data mining pada dataset produk ritel fashion Adidas adalah untuk mengidentifikasi pola-pola dan wawasan yang berguna bagi perusahaan dalam mengambil keputusan strategis. terkait manajemen persediaan, optimasi saluran penjualan, pengembangan produk, pemasaran yang lebih efektif, serta perencanaan keuangan jangka panjang. Melalui analisis data mining, Adidas berharap untuk dapat memahami perilaku pembelian pelanggan, tren produk, preferensi konsumen, serta faktor-faktor lain yang memengaruhi kinerja bisnis dari Adidas. Dengan pemahaman yang lebih mendalam tentang data, Adidas dapat mengoptimalkan strategi pemasaran, manajemen persediaan, pengembangan produk, dan pengambilan keputusan lainnya untuk mencapai tujuan bisnis mereka secara efektif.
#
# #Project Plan
# Rencana proyek untuk analisis dataset ini dengan membuat pengumpulan data pada komprehensif dari berbagai sumber termasuk penjualan, investaris, dan data pelanggan. Selanjutkan akan dilakukan pembersihan data untuk menghilangkan duplikasi, nilai-nilai yang hilang, dan kesalahan lainnya agar data lebih akurat. Kemudian dilakukan analisis pada data menggunakan data mining untuk mengidentifikasi dari pola-pola, tren, dan wawasan yang relavan. Kemudian hasil dari analisis ini akan digunakan untuk merumuskan srategi bisnis, seperti peningkatan pemasaran dan manajemen persediaan yang lebih efisien. Dan dilakukan evaluasi dan penyususnana laporan untuk mengkomunikasikan hasil analisis kepada pemangku kepentingan dan membuat rekomendasi untuk tindakan selanjutnya.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %%
df = pd.read_csv ("adidas.csv")

# %% [markdown]
# Pada data diatas ini didapatkan dari Adidas Fashion Retail Product Dataset yang terdapat di link berikut :
# https://www.kaggle.com/datasets/thedevastator/adidas-fashion-retail-products-dataset-9300-prod

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
print("Baris :",df.shape[0])
print("Kolom :",df.shape[1])
# Out:
# Baris : 845
# Kolom : 21

# %% [markdown]
# Dari data diatas ini dapat diketahui bahwa dataset memiliki Baris 845, dengan kolom 21

# %% [markdown]
# ####Informasi Lanjutan

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           845 non-null    int64
#  1   url             845 non-null    object
#  2   name            845 non-null    object
#  3   sku             845 non-null    object
#  4   selling_price   845 non-null    int64
#  5   original_price  829 non-null    object
#  6   currency        845 non-null    object
#  7   availability    845 non-null    object
#  8   color           845 non-null    object
#  9   category        845 non-null    object
#  10  source          845 non-null    object
#  11  source_website  845 non-null    object
#  12  breadcrumbs     845 non-null    object
#  13  description     845 non-null    object
#  14  brand           845 non-null    object
#  15  images          845 non-null    object
#  16  country         845 non-null    object
# ...

# %% [markdown]
# 1.   Pada info yang terdapat diatas, memeiliki total data columns 21,
# 2.   pada column index 0 dengan data 845 dan type data int64.
# 3.   Pada column url 1, name 2, sku 3, memiliki data sama yaitu 845 dan type data object.
# Pada column seliing_price 4 dengan data 845 dan type data int4.
# 4. Pada column original_price 5, dengan data 829 dan type data object.
# 5.  Pada column currency 6, availability 7, color 8, category 9, source 10, source_website 11, breadcrumbs 12, description 13, brand 14, images 15, country 16, language 17, memiliki data sama yaitu dengan data 845 dan type data object.
# 6.  Pada column average_rating 18, memiliki data 845 dengan type data float64. Pada column reviews_count 19, memiliki data 845 dengan type data int64.
# 7.  Pada column crawled_at 20, memiliki data 845 dengan type data object.

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
print("data statistik : ",df.describe())
# Out:
# data statistik :              index  selling_price  average_rating  reviews_count
# count  845.000000     845.000000      845.000000     845.000000
# mean   422.000000      53.192899        4.608402     426.178698
# std    244.074784      31.411645        0.293795    1229.158277
# min      0.000000       9.000000        1.000000       1.000000
# 25%    211.000000      28.000000        4.500000      19.000000
# 50%    422.000000      48.000000        4.700000      68.000000
# 75%    633.000000      70.000000        4.800000     314.000000
# max    844.000000     240.000000        5.000000   11750.000000

# %% [markdown]
# 1.  Kolom index menunjukkan distribusi indeks dengan mean sekitar 422 dan nilai maksimum 844.
# 2. Kolom selling_price menggambarkan variasi harga jual produk dengan mean sekitar 53 dan rentang dari harga minimum 9 hingga maksimum 240.
# 3. Kolom average_rating memberikan informasi tentang penilaian rata-rata produk dengan mean sekitar 4.6 dan rentang dari penilaian minimum 1 hingga maksimum 5, menunjukkan kecenderungan umum penilaian tinggi.
# 4.  kolom reviews_count menggambarkan distribusi jumlah ulasan produk dengan mean sekitar 426, tetapi dengan standar deviasi yang tinggi, menunjukkan variasi yang besar dalam jumlah ulasan, dari minimum 1 hingga maksimum 11750.

# %% [markdown]
# ##**Exploratory Data Analysis**

# %% [markdown]
# ##Variabel Tunggal

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['average_rating'], bins=30, kde=True, color='blue')
plt.title('Distribusi Rating Produk Adidas Fashion Retail')
plt.xlabel('Rating')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Dapat terlihat bahwa sebagian besar produk memiliki rating yang tinggi, ditandai dengan puncak histogram yang terletak di sekitar nilai rating yang tinggi. Hal ini menunjukkan bahwa mayoritas produk Adidas dalam kategori fashion retail mendapatkan penilaian yang baik dari para pelanggan. Namun, ada juga sejumlah produk yang mendapatkan rating rendah, meskipun jumlahnya relatif sedikit.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
import matplotlib.pyplot as plt

nilai_kosong = df.isnull().sum()

plt.figure(figsize=(10, 6))
plt.bar(nilai_kosong.index, nilai_kosong.values, color='skyblue')
plt.xlabel('Kolom')
plt.ylabel('Jumlah Nilai Kosong')
plt.title('Histogram Jumlah Nilai Kosong per Kolom')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Pada kolom index, url, name, sku, selling_price, currency, availability, color, category, source, source_website, breadcrumbs, description, brand, images, country, language, average_rating, reviews_count, dan crawled_at tidak memiliki nilai kosong, karena jumlah nilai kosongnya adalah nol untuk setiap kolom tersebut. Namun, Pada kolom original_price memiliki 16 nilai kosong. Hal ini menunjukkan bahwa terdapat 16 entri dalam data yang tidak memiliki harga asli (original price) yang tercatat.

# %% [markdown]
# ####Outliers Values

# %%
def detect_outliers(df):
    outliers_dict = {}
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
            outliers_count = outliers.shape[0]
            outliers_dict[column] = outliers_count
    return outliers_dict

outliers_result = detect_outliers(df)
print("Outliers count in each column:")
print(outliers_result)
# Out:
# Outliers count in each column:
# {'index': 0, 'selling_price': 19, 'average_rating': 35, 'reviews_count': 93}

# %% [markdown]
# 1. Pada Index: Tidak ada outliers dalam kolom ini, dengan jumlah outliers sebesar 0. Ini menunjukkan bahwa semua nilai dalam kolom indeks berada dalam rentang yang dianggap normal.
# 2. Pada Selling Price: Terdapat 19 outliers dalam kolom harga jual. Outliers dalam konteks ini adalah nilai-nilai yang jauh dari rentang nilai yang dianggap normal, mungkin merupakan harga yang sangat tinggi atau rendah dibandingkan dengan harga rata-rata produk.
# 3. Pada Average Rating: Terdapat 35 outliers dalam kolom rating rata-rata. Outliers dalam konteks ini bisa berarti produk-produk yang mendapatkan penilaian yang sangat tinggi atau rendah dibandingkan dengan rata-rata umum.
# 4. Pada Reviews Count: Terdapat 93 outliers dalam kolom jumlah ulasan. Outliers dalam konteks ini mungkin menunjukkan produk-produk yang menerima jumlah ulasan yang sangat tinggi atau rendah dibandingkan dengan produk lainnya.

# %% [markdown]
# ####Duplicated Values

# %%
def check_duplicates(df):
    duplicates_dict = {}
    for column in df.columns:
        duplicates_count = df.duplicated(subset=[column]).sum()
        duplicates_dict[column] = duplicates_count
    return duplicates_dict

duplicates_result = check_duplicates(df)
print("Duplikat count in each column:")
print(duplicates_result)
# Out:
# Duplikat count in each column:
# {'index': 0, 'url': 0, 'name': 414, 'sku': 0, 'selling_price': 772, 'original_price': 802, 'currency': 844, 'availability': 843, 'color': 827, 'category': 842, 'source': 844, 'source_website': 844, 'breadcrumbs': 823, 'description': 285, 'brand': 844, 'images': 0, 'country': 844, 'language': 844, 'average_rating': 829, 'reviews_count': 634, 'crawled_at': 0}

# %% [markdown]
# 1. Index: Tidak ada nilai duplikat dalam kolom indeks.
# 2. URL: Tidak ada nilai duplikat dalam kolom URL.
# 3. Name: Terdapat 414 nilai duplikat dalam kolom nama produk.
# 4. Selling Price: Terdapat 772 nilai duplikat dalam kolom harga jual.
# 5. Original Price: Terdapat 802 nilai duplikat dalam kolom harga asli.
# 6. Currency: Terdapat 844 nilai duplikat dalam kolom mata uang.
# 7. Availability: Terdapat 843 nilai duplikat dalam kolom ketersediaan produk.
# 8. Color: Terdapat 827 nilai duplikat dalam kolom warna produk.
# 9. Category: Terdapat 842 nilai duplikat dalam kolom kategori produk.
# 10. Source dan Source Website: Terdapat 844 nilai duplikat dalam kolom sumber dan website sumber.
# 11. Breadcrumbs: Terdapat 823 nilai duplikat dalam kolom breadcrumbs.
# 12. Description: Terdapat 285 nilai duplikat dalam kolom deskripsi produk.
# 13. Brand: Semua nilai dalam kolom merek memiliki duplikat (jumlah duplikat 844).
# 14. Images: Tidak ada nilai duplikat dalam kolom gambar, dengan jumlah duplikat sebesar 0.
# 15. Country dan Language: Terdapat 844 nilai duplikat dalam kolom negara dan bahasa.
# 16. Average Rating: Terdapat 829 nilai duplikat dalam kolom rating rata-rata.
# 17. Reviews Count: Terdapat 634 nilai duplikat dalam kolom jumlah ulasan.
# 18. Crawled At: Tidak ada nilai duplikat dalam kolom tanggal pengambilan data, dengan jumlah duplikat sebesar 0.

# %% [markdown]
# #**Check Point Data Preparation**

# %% [markdown]
# #**Data Cleaning**

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Algoritma C4.5
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #**Penanganan Missing Values**

# %% [markdown]
# ####**Pengecekkan MIssing Values**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# index             0.000000
# url               0.000000
# name              0.000000
# sku               0.000000
# selling_price     0.000000
# original_price    1.893491
# currency          0.000000
# availability      0.000000
# color             0.000000
# category          0.000000
# source            0.000000
# source_website    0.000000
# breadcrumbs       0.000000
# description       0.000000
# brand             0.000000
# images            0.000000
# country           0.000000
# language          0.000000
# average_rating    0.000000
# reviews_count     0.000000
# crawled_at        0.000000
# dtype: float64

# %% [markdown]
# Dari Data diatas menunjukan hasil dari analisis variabel dalam dataset, yang dimana hanya variabel "original_prince" yang memiliki nilai yang tidak nol yaitu (1.893491), sementara pada variabel yang lainnya memiliki nilai nol.

# %% [markdown]
# Nilai Kosong Pada Kolom Original_Price

# %%
df[df['original_price'].isnull()]
# Out:
#     index                                                url  \
# 0       0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1       1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2       2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3       3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4       4  https://www.adidas.com/us/mesh-broken-stripe-p...
# 5       5  https://www.adidas.com/us/eqt-spikeless-golf-s...
# 6       6  https://www.adidas.com/us/adicross-hybrid-shor...
# 7       7  https://www.adidas.com/us/tiro-21-windbreaker/...
# 8       8  https://www.adidas.com/us/classic-3-stripes-sw...
# 9       9  https://www.adidas.com/us/tiro-21-windbreaker/...
# 10     10  https://www.adidas.com/us/formotion-sculpt-bik...
# 11     11  https://www.adidas.com/us/athletic-cushioned-c...
# 12     12  https://www.adidas.com/us/inter-miami-cf-home-...
# 13     13  https://www.adidas.com/us/cushioned-mid-crew-s...
# ...

# %% [markdown]
# Pada kolom Original_Price ini Setelah menemukan adanya nilai kosong diperlukan untuk menghapus baris yang memiliki nilai kosong ini.

# %% [markdown]
# #####**Hapus Missing Values**

# %%
df = df.drop('original_price', axis=1)

# %%
df
# Out:
#      index                                                url  \
# 0        0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1        1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2        2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3        3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4        4  https://www.adidas.com/us/mesh-broken-stripe-p...
# ..     ...                                                ...
# 840    840  https://www.adidas.com/us/supernova-plus-shoes...
# 841    841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842    842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843    843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844    844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 name     sku  selling_price  \
# 0                                       Beach Shorts  FJ5089             40
# ...

# %% [markdown]
# setelah Menghapus missing values di mana baris atau kolom yang mengandung nilai yang hilang dihapus dari dataset. pengguna memilih apakah akan menghapus baris atau kolom yang mengandung missing values. Meskipun penghapusan missing values dapat membersihkan dataset dari nilai yang hilang.

# %% [markdown]
# #####**Pengecekkan Ulang**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                 Null Ratio %
# index                    0.0
# url                      0.0
# name                     0.0
# sku                      0.0
# selling_price            0.0
# currency                 0.0
# availability             0.0
# color                    0.0
# category                 0.0
# source                   0.0
# source_website           0.0
# breadcrumbs              0.0
# description              0.0
# brand                    0.0
# images                   0.0
# country                  0.0
# language                 0.0
# average_rating           0.0
# reviews_count            0.0
# crawled_at               0.0

# %% [markdown]
# DIlihat pada data diatas ini menunjukan bahwa Persentase nilai null untuk setiap kolom adalah 0%, yang mengindikasikan bahwa dataset tersebut sudah bersih dari nilai kosong.

# %% [markdown]
# ###**Penanganan Duplicated Values**

# %% [markdown]
# #####**Pengecekkan Nilai Duplikat**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, url, name, sku, selling_price, currency, availability, color, category, source, source_website, breadcrumbs, description, brand, images, country, language, average_rating, reviews_count, crawled_at]
# Index: []

# %% [markdown]
# Dari pengecekkan nilai duplikat ini proses untuk memastikan bahwa tidak ada baris yang sama persis dalam dataset. Dalam konteks data yang diberikan, pengecekan nilai duplikat akan memeriksa apakah ada entri yang memiliki nilai yang sama untuk setiap kolom.

# %% [markdown]
# #####**Hapus Nilai Duplikat**

# %%
df = df.drop_duplicates()

# %% [markdown]
# #####**Pengecekkan Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)

# %%
boxplot = df.drop('index', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# Dari data diatas ini  bertujuan untuk mengidentifikasi nilai yang ekstrem atau tidak biasa dalam dataset,Outliers dapat mempengaruhi hasil analisis dan model yang dibangun dari data.

# %% [markdown]
# #**Pengecekan Ulang**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom           Persentase Outliers
# index                      0.000000
# selling_price              2.248521
# average_rating             4.142012
# reviews_count             11.005917

# %%
boxplot = df.drop('index', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# #**Construct Data**

# %% [markdown]
# Construct Data ini digunakan untuk langkah penting dalam memastikan bahwa data yang digunakan untuk evaluasi atau analisis telah dipersiapkan dengan baik dan sesuai dengan tujuan yang diinginkan. Dengan memeriksa struktur data, kebersihan, dan relevansi variabel, serta memastikan bahwa data tidak mengandung nilai yang hilang atau duplikat, Anda dapat memastikan bahwa hasil analisis yang dihasilkan dapat dipercaya dan relevan untuk membuat keputusan yang tepat.

# %% [markdown]
# #**Pengecekkan Hasil**

# %%
df.head()
# Out:
#    index                                                url  \
# 0      0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1      1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2      2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3      3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4      4  https://www.adidas.com/us/mesh-broken-stripe-p...
#
#                                               name     sku  selling_price  \
# 0                                     Beach Shorts  FJ5089             40
# 1        Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# 2                               Mexico Away Jersey  GC7946             70
# 3  Five Ten Hiangle Pro Competition Climbing Shoes  FV4744            160
# 4                    Mesh Broken-Stripe Polo Shirt  GM0239             65
#
#   currency availability  color  category                source  \
# 0      USD      InStock  Black  Clothing  adidas United States
# ...

# %% [markdown]
# #**Data Reduction**

# %% [markdown]
# Pada Data Reduction ini proses mengurangi jumlah atribut atau instance dalam sebuah dataset. Tujuan dari data reduction adalah untuk memperbaiki efisiensi dan kinerja analisis data, khususnya dalam konteks data yang sangat besar atau kompleks. Data reduction memungkinkan analisis yang lebih cepat dan efisien tanpa kehilangan informasi penting, sehingga memungkinkan pengambilan keputusan yang lebih tepat dan efektif.

# %% [markdown]
# ###**Mengurangi Fitur - Fitur Yang Kurang Relevan**

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = df.drop(['index','breadcrumbs','availability'], axis=1)

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4  https://www.adidas.com/us/mesh-broken-stripe-p...
#
#                                               name     sku  selling_price  \
# 0                                     Beach Shorts  FJ5089             40
# 1        Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# 2                               Mexico Away Jersey  GC7946             70
# 3  Five Ten Hiangle Pro Competition Climbing Shoes  FV4744            160
# 4                    Mesh Broken-Stripe Polo Shirt  GM0239             65
#
#   currency  color  category                source          source_website  \
# 0      USD  Black  Clothing  adidas United States  https://www.adidas.com
# ...

# %% [markdown]
# #**Data Transformation**

# %% [markdown]
# Pada Data Transformation digunakan untuk proses mengubah struktur atau format data dari satu bentuk ke bentuk lainnya. Tujuan utama dari data transformation adalah untuk mempersiapkan data agar sesuai dengan kebutuhan analisis atau pemodelan yang akan dilakukan. Proses transformasi data melibatkan beberapa langkah seperti normalisasi, pengkodean kategori, pengubahan skala, transformasi variabel, dan lainnya.

# %% [markdown]
# #**Mapping**

# %% [markdown]
# mapping digunakan untuk menghubungkan atau menghubungkan informasi antara dua set data yang berbeda, yang mungkin memiliki struktur atau format yang berbeda.

# %%
print(df.columns)
# Out:
# Index(['url', 'name', 'sku', 'selling_price', 'currency', 'color', 'category',
#        'source', 'source_website', 'description', 'brand', 'images', 'country',
#        'language', 'average_rating', 'reviews_count', 'crawled_at'],
#       dtype='object')

# %%
df['category'].map({'Clothing':1, 'Shoes':0})
df['language'].map({'en':1,}).astype(int)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 840    1
# 841    1
# 842    1
# 843    1
# 844    1
# Name: language, Length: 845, dtype: int64

# %%
df
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...
# 2    https://www.adidas.com/us/mexico-away-jersey/G...
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...
# ..                                                 ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...
# 841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 name     sku  selling_price  \
# 0                                       Beach Shorts  FJ5089            NaN
# 1          Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            NaN
# ...

# %% [markdown]
# #**Encoding**

# %% [markdown]
# Encoding digunakan untuk proses mengubah data dari satu bentuk ke bentuk lain yang dapat digunakan untuk analisis atau pemodelan.Encoding memungkinkan kita untuk memproses data kategorikal dalam analisis atau pemodelan, meningkatkan kinerja dan akurasi hasil.

# %%
df = pd.get_dummies(df)

# %% [markdown]
# #**Pengecekkan Hasil**

# %%
df.head()
# Out:
#    selling_price  category  average_rating  reviews_count  \
# 0            NaN       NaN             4.5             35
# 1            NaN       NaN             4.8              4
# 2            NaN       NaN             4.9             42
# 3            NaN       NaN             3.7              7
# 4            NaN       NaN             4.7             11
#
#    url_https://www.adidas.com/us/3-stripes-crew-socks-3-pairs/EX6575.html  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    url_https://www.adidas.com/us/3-stripes-low-cut-socks-3-pairs/EX6581.html  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# ...
